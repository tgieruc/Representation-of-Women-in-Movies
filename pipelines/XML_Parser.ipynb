# %%
import pandas as pd
from lxml import etree as ET
import os
import gzip
from tqdm.auto import tqdm

# %% [markdown]
# First our function definitions

# %% [markdown]
# Get word lemma is used to find the words and their lemmas given a character and a dependency type which is the arguement in this case

# %%
def get_word_lemma(root, argument, data, data_key):

    deps = root.findall(f'./document/sentences/sentence/collapsed-ccprocessed-dependencies/dep[@type="{argument}"]')
    for name in data.keys():
        for element in deps:
            if element.find('dependent').text.casefold() in name.casefold().split(' '):
                gov = element.find('governor')
                data[name][data_key]['word'].append(gov.text)
                idx = (gov.attrib['idx'])
                sentence = gov.getparent().getparent().getparent()
                data[name][data_key]['lemma'].append(sentence.findall(f'.//tokens/token[@id="{idx}"]/lemma')[0].text)

# %% [markdown]
# Get APA takes in a list of characters and an xml string and grabs all of the agent verbs and patient verbs per character and returns it in a dictionary. The rules are according to the paper that the data is from. Currently it doesn't grab any attributes because I cannot understand the rule used for that.
#
# Dictionary structure (open in markup mode to read easily)
# `
# {
#     Character Name:
#                     {
#                         agent:
#                                 {
#                                     word: [list of all of the words associated with the character],
#                                     lemma: [list of all of the lemmas associated with the above words]
#                                 }
#                         patient:
#                                 {
#                                     word: [list of all of the words associated with the character],
#                                     lemma: [list of all of the lemmas associated with the above words]
#                                 }
#                         attribute:
#                                 {
#                                     word: [list of all of the words associated with the character],
#                                     lemma: [list of all of the lemmas associated with the above words]
#                                 }
#                     }
# }
#
# - Character name:
#     - agent:
#         - word: [list of all of the words associated with the character],
#         - lemma: [list of all of the lemmas associated with the above words]
#     - patient:
#         - word: [list of all of the words associated with the character],
#         - lemma: [list of all of the lemmas associated with the above words]
#     - attribute:
#         - word: [list of all of the words associated with the character],
#         - lemma: [list of all of the lemmas associated with the above words]

# %%
def get_APA(chars, file):
    #function to get the root

    root = ET.fromstring(file)
    #root = tree.getroot()

    agent = ['nsubj', 'agent']
    patient = ['dobj', 'nsubjpass', 'iobj']
    abute_gov = ['nsubj', 'appos'] #governors
    abute_dep = ['nsubj', 'appos', 'amod', 'nn'] #dependants of an entity mention
    
    data = {}
    for name in chars:
        data[name] = {
            'agent':{'word':[],'lemma':[]},
            'patient':{'word':[],'lemma':[]},
            'attribute':{'word':[],'lemma':[]}
            }

    #The first two objects are very easy to get and I can use the function I made
    for argument in agent:
        get_word_lemma(root,argument,data,'agent')
    for argument in patient:
        get_word_lemma(root,argument,data,'patient')

    #The following is to grab all of the patient actions that are any preposition
    pre_deps = root.xpath('.//document/sentences/sentence/collapsed-ccprocessed-dependencies/dep[contains(@type,"prep_")]')
    for name in data.keys():
        for element in pre_deps:
            if element.find('dependent').text.casefold() in name.casefold().split(' '):
                gov = element.find('governor')
                data[name]['patient']['word'].append(gov.text)
                idx = (gov.attrib['idx'])
                sentence = gov.getparent().getparent().getparent()
                data[name]['patient']['lemma'].append(sentence.findall(f'.//tokens/token[@id="{idx}"]/lemma')[0].text)

    

    #to get the one with the real expression 

    return data

# %% [markdown]
# The parser is the function that will be called. The df that is passed into it is a dataframe where each row has two entries. The first is the movie wiki id and the second is a list of all of the characters in a movie. The data_path should go from the current directory to the folder that contains all of the zipped xml folders
#
# This parser will create a new folder in the data_path and save to csv a DataFrame of the following structure:
#
# movie wiki id | character name | action verb words | action verb lemmas | patient verb words | paitent verb lemmas | attribute words | attribute lemmas
#
# This was done so if the code fails during the iterations that progress is not lost.

# %%
def proccessed_summary_parser(df, data_path):
    #first make the file director if it doesn't exist
    if not os.path.exists(data_path+'parsed_data/'):
        os.mkdir(data_path+'parsed_data/')

    unfound_files = []

    for _, movie in tqdm(df.iterrows()):
        gzip_file_path = data_path+movie[movie.index[0]]+'.xml.gz'
        folder_path =data_path+'parsed_data/'
        save_path = folder_path+movie[movie.index[0]]+'.p'
        final_data = []
        if not os.path.exists(save_path):
            if os.path.exists(gzip_file_path):
                with gzip.open(gzip_file_path,'r') as folder:
                    file = folder.read()
                    data = get_APA(movie[movie.index[1]], file)
                    for char, words in data.items():
                        row = {'movie':movie[movie.index[0]]}
                        row['character'] = char
                        for word_cat, word_lemma in words.items():
                            row[f'{word_cat}_word'] = word_lemma['word']
                            row[f'{word_cat}_lemma'] = word_lemma['lemma']
                        final_data.append(row)
                    pd.DataFrame(final_data).to_pickle(save_path)
            else:
                missing = {
                    'file_path': gzip_file_path
                }
                unfound_files.append(missing)
                print(f'{gzip_file_path} doesn\'t exist.')
    pd.DataFrame(unfound_files).to_pickle(data_path+'unfound_files.p')

# %% [markdown]
# We can then use the character name and wiki movie id to create a unqiue identifier to merge this with the main CMU character dataset

# %% [markdown]
# Let's make the DataFrame that we will pass into our function to parse all of the plot summaries, this needs to contain the movie ID in one column and then a list containing all of the characters in the other

# %%
characters = pd.read_pickle('./pickle files-20221103T070047Z-001/pickle files/characters.p')
print(len(characters))
characters.head()
# Out:
# 450263
#    movie_wiki_id movie_freebase_id release_date              character_name  \
# 0       975900.0         /m/03vyhn   2001-08-24                    Akooshay
# 1       975900.0         /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard
# 2       975900.0         /m/03vyhn   2001-08-24         Desolation Williams
# 3       975900.0         /m/03vyhn   2001-08-24          Sgt Jericho Butler
# 4       975900.0         /m/03vyhn   2001-08-24             Bashira Kincaid
#
#                       birth gender  height   ethnicity          actor_name  \
# 0 1958-08-26 00:00:00+00:00      F   1.620         NaN      Wanda De Jesus
# 1 1974-08-15 00:00:00+00:00      F   1.780  /m/044038p  Natasha Henstridge
# 2 1969-06-15 00:00:00+00:00      M   1.727     /m/0x67            Ice Cube
# 3 1967-09-12 00:00:00+00:00      M   1.750         NaN       Jason Statham
# 4 1977-09-25 00:00:00+00:00      F   1.650         NaN         Clea DuVall
#
#    actor_age freebase_character_actor_map_id freebase_character_id  \
# 0       42.0                      /m/0bgchxw            /m/0bgcj3x
# 1       27.0                       /m/0jys3m            /m/0bgchn4
# 2       32.0                       /m/0jys3g            /m/0bgchn_
# 3       33.0                      /m/02vchl6            /m/0bgchnq
# 4       23.0                      /m/02vbb3r            /m/0bgchp9
#
#   freebase_actor_id  release_year  birth_year
# 0        /m/03wcfv7        2001.0      1958.0
# 1         /m/0346l4        2001.0      1974.0
# 2        /m/01vw26l        2001.0      1969.0
# 3         /m/034hyc        2001.0      1967.0
# 4         /m/01y9xg        2001.0      1977.0

# %% [markdown]
# First we will group all of the characters by their movie_wiki_id and then iterate over each group to create a large data list that we can turn into a DataFrame. We are only going to loop over rows that have a character name, otherwise we aren't going to be able to grab any infromation. Note we have to convert the wiki movie ids into strings otherwise our function won't be able to concatenate them with our file paths

# %%
print(f'number of rows with character names {len(characters[characters.character_name.notna()])}')
movie_id_groups = characters[characters.character_name.notna()].groupby('movie_wiki_id')

data = []

for movie_wiki_id, group in tqdm(movie_id_groups):
    chars = []
    for ind, row in group.iterrows():
        chars.append(row.character_name)
    data_row ={
        'movie_wiki_id': str(int(movie_wiki_id)),
        'characters': chars
    }
    data.append(data_row)

df = pd.DataFrame(data)
df
# Out:
# number of rows with character names 192715
#   0%|          | 0/32564 [00:00<?, ?it/s]
#       movie_wiki_id                                         characters
# 0              3217  [S-Mart Clerk, Fake shemp, Ash Williams, Evil ...
# 1              3746  [J.F. Sebastian, Rick Deckard, Roy Batty, Rach...
# 2              3837  [Gabby Johnson, Taggart, Rev. Johnson, Mongo, ...
# 3              3947  [Don Vallens, Dorothy Vallens, Jeffrey Beaumon...
# 4              4227                                     [Barry Lyndon]
# ...             ...                                                ...
# 32559      37196243  [Carlina White, Ann Pettway, Joy White, Carl W...
# 32560      37322106                                      [Major Samar]
# 32561      37373877                   [Beth Patterson, Jennifer Jones]
# 32562      37478048                                             [Ajay]
# 32563      37501922                        [John Hunter, Craig Murphy]
#
# [32564 rows x 2 columns]

# %% [markdown]
# Let's just double check that we have all of the characters

# %%
i=0
for indx, row in df.iterrows():
    i+= len(row.characters)
i
# Out:
# 192715

# %% [markdown]
# Now let's pass in our dataframe into our function and parse all of the XMLs

# %%
data_path = './corenlp_plot_summaries/corenlp_plot_summaries/'

proccessed_summary_parser(df,data_path)
# Out:
# 0it [00:00, ?it/s]
# ./corenlp_plot_summaries/corenlp_plot_summaries/27073.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/33560.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/42221.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/47661.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/52942.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/60173.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/61170.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/61173.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/61491.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/61498.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/62180.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/65956.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/66205.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/68145.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/70647.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/73413.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/73419.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/73457.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/73460.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/73497.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/74856.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/74859.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/74963.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/76300.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/76320.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/77637.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/77685.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/77751.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/101398.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/101401.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/101408.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/103022.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/106337.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/113227.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/113436.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/129542.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/144765.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/145928.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/147829.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/154688.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/155392.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/156745.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/161438.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/161500.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/161779.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/161924.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/162147.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/163775.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/164388.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/168551.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/168570.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/168586.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/172045.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/177731.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/177824.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/180978.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/181339.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/183447.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/183610.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/183744.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/183847.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/184987.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/187115.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/190392.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/190398.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/193874.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/206737.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/210229.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/217765.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/219270.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/221271.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/224069.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/224224.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/225477.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/225514.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/226189.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/230546.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/240369.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/240370.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/241475.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/241598.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/242550.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/246556.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/246775.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/246789.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/247709.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/250718.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/250837.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/254132.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/255482.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/261118.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/268087.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/282441.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/285129.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/286850.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/293952.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/297010.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/306080.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/310436.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/311915.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/327427.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/330659.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/334649.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/338908.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/351649.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/352505.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/363929.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/364835.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/370112.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/373905.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/375788.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/379529.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/380123.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/387337.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/389567.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/390436.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/397310.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/402731.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/402890.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/408474.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/423546.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/430419.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/431530.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/436308.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/438116.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/452891.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/454237.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/460605.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/464292.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/468229.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/471532.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/471547.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/471549.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/471557.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/472897.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/479905.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/490979.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/498211.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/507679.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/533378.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/541495.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/545599.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/555776.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/558882.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/568666.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/569809.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/569867.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/581710.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/586746.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/588698.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/594219.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/595332.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/595587.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/596141.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/600132.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/607433.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/612710.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/617535.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/619956.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/624433.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/628302.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/634058.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/637187.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/642013.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/642695.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/643173.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/646555.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/649185.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/649482.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/675832.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/679040.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/679577.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/679619.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/680435.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/682722.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/689549.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries/690993.xml.gz doesn't exist.
# ./corenlp_plot_summaries/corenlp_plot_summaries